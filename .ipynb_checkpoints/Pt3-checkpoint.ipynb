# %%
# !pip install torch torchvision matplotlib tensorboard
# Out:
# Requirement already satisfied: torch in ./liuhe/lib/python3.11/site-packages (2.0.1)
# Requirement already satisfied: torchvision in ./liuhe/lib/python3.11/site-packages (0.15.2)
# Requirement already satisfied: matplotlib in ./liuhe/lib/python3.11/site-packages (3.8.0)
# Collecting tensorboard
#   Obtaining dependency information for tensorboard from https://files.pythonhosted.org/packages/73/a2/66ed644f6ed1562e0285fcd959af17670ea313c8f331c46f79ee77187eb9/tensorboard-2.14.1-py3-none-any.whl.metadata
#   Using cached tensorboard-2.14.1-py3-none-any.whl.metadata (1.7 kB)
# Requirement already satisfied: filelock in ./liuhe/lib/python3.11/site-packages (from torch) (3.12.2)
# Requirement already satisfied: typing-extensions in ./liuhe/lib/python3.11/site-packages (from torch) (4.7.1)
# Requirement already satisfied: sympy in ./liuhe/lib/python3.11/site-packages (from torch) (1.12)
# Requirement already satisfied: networkx in ./liuhe/lib/python3.11/site-packages (from torch) (3.1)
# Requirement already satisfied: jinja2 in ./liuhe/lib/python3.11/site-packages (from torch) (3.1.2)
# Requirement already satisfied: numpy in ./liuhe/lib/python3.11/site-packages (from torchvision) (1.25.1)
# Requirement already satisfied: requests in ./liuhe/lib/python3.11/site-packages (from torchvision) (2.31.0)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in ./liuhe/lib/python3.11/site-packages (from torchvision) (10.0.0)
# Requirement already satisfied: contourpy>=1.0.1 in ./liuhe/lib/python3.11/site-packages (from matplotlib) (1.1.1)
# Requirement already satisfied: cycler>=0.10 in ./liuhe/lib/python3.11/site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in ./liuhe/lib/python3.11/site-packages (from matplotlib) (4.43.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in ./liuhe/lib/python3.11/site-packages (from matplotlib) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in ./liuhe/lib/python3.11/site-packages (from matplotlib) (23.1)
# Requirement already satisfied: pyparsing>=2.3.1 in ./liuhe/lib/python3.11/site-packages (from matplotlib) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in ./liuhe/lib/python3.11/site-packages (from matplotlib) (2.8.2)
# Collecting absl-py>=0.4 (from tensorboard)
#   Obtaining dependency information for absl-py>=0.4 from https://files.pythonhosted.org/packages/01/e4/dc0a1dcc4e74e08d7abedab278c795eef54a224363bb18f5692f416d834f/absl_py-2.0.0-py3-none-any.whl.metadata
#   Using cached absl_py-2.0.0-py3-none-any.whl.metadata (2.3 kB)
# Collecting grpcio>=1.48.2 (from tensorboard)
#   Obtaining dependency information for grpcio>=1.48.2 from https://files.pythonhosted.org/packages/bb/1c/4741e490b93488e077e36543b0acbfece41314b5a1ffae05bc7e2e9b3375/grpcio-1.59.0-cp311-cp311-macosx_10_10_universal2.whl.metadata
#   Using cached grpcio-1.59.0-cp311-cp311-macosx_10_10_universal2.whl.metadata (4.0 kB)
# Collecting google-auth<3,>=1.6.3 (from tensorboard)
#   Obtaining dependency information for google-auth<3,>=1.6.3 from https://files.pythonhosted.org/packages/39/7c/2e4fa55a99f83ef9ef229ac5d59c44ceb90e2d0145711590c0fa39669f32/google_auth-2.23.3-py2.py3-none-any.whl.metadata
#   Downloading google_auth-2.23.3-py2.py3-none-any.whl.metadata (4.2 kB)
# Collecting google-auth-oauthlib<1.1,>=0.5 (from tensorboard)
#   Using cached google_auth_oauthlib-1.0.0-py2.py3-none-any.whl (18 kB)
# Collecting markdown>=2.6.8 (from tensorboard)
#   Obtaining dependency information for markdown>=2.6.8 from https://files.pythonhosted.org/packages/bb/c1/50caaec6cadc1c6adc8fe351e03bd646d6e4dd17f55fca0f4c8d7ea8d3e9/Markdown-3.5-py3-none-any.whl.metadata
#   Downloading Markdown-3.5-py3-none-any.whl.metadata (7.1 kB)
# Requirement already satisfied: protobuf>=3.19.6 in ./liuhe/lib/python3.11/site-packages (from tensorboard) (4.23.4)
# Requirement already satisfied: setuptools>=41.0.0 in ./liuhe/lib/python3.11/site-packages (from tensorboard) (67.8.0)
# Requirement already satisfied: six>1.9 in ./liuhe/lib/python3.11/site-packages (from tensorboard) (1.12.0)
# Collecting tensorboard-data-server<0.8.0,>=0.7.0 (from tensorboard)
#   Obtaining dependency information for tensorboard-data-server<0.8.0,>=0.7.0 from https://files.pythonhosted.org/packages/da/61/6e9ff8258422d287eec718872fb71e05324356722ab658c8afda25f51539/tensorboard_data_server-0.7.1-py3-none-any.whl.metadata
#   Using cached tensorboard_data_server-0.7.1-py3-none-any.whl.metadata (1.1 kB)
# Requirement already satisfied: werkzeug>=1.0.1 in ./liuhe/lib/python3.11/site-packages (from tensorboard) (2.3.6)
# Collecting cachetools<6.0,>=2.0.0 (from google-auth<3,>=1.6.3->tensorboard)
#   Obtaining dependency information for cachetools<6.0,>=2.0.0 from https://files.pythonhosted.org/packages/a9/c9/c8a7710f2cedcb1db9224fdd4d8307c9e48cbddc46c18b515fefc0f1abbe/cachetools-5.3.1-py3-none-any.whl.metadata
#   Downloading cachetools-5.3.1-py3-none-any.whl.metadata (5.2 kB)
# Collecting pyasn1-modules>=0.2.1 (from google-auth<3,>=1.6.3->tensorboard)
#   Downloading pyasn1_modules-0.3.0-py2.py3-none-any.whl (181 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 181.3/181.3 kB 2.8 MB/s eta 0:00:00 MB/s eta 0:00:01
# Collecting rsa<5,>=3.1.4 (from google-auth<3,>=1.6.3->tensorboard)
#   Downloading rsa-4.9-py3-none-any.whl (34 kB)
# Collecting requests-oauthlib>=0.7.0 (from google-auth-oauthlib<1.1,>=0.5->tensorboard)
#   Using cached requests_oauthlib-1.3.1-py2.py3-none-any.whl (23 kB)
# Requirement already satisfied: charset-normalizer<4,>=2 in ./liuhe/lib/python3.11/site-packages (from requests->torchvision) (3.2.0)
# Requirement already satisfied: idna<4,>=2.5 in ./liuhe/lib/python3.11/site-packages (from requests->torchvision) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in ./liuhe/lib/python3.11/site-packages (from requests->torchvision) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in ./liuhe/lib/python3.11/site-packages (from requests->torchvision) (2023.7.22)
# Requirement already satisfied: MarkupSafe>=2.1.1 in ./liuhe/lib/python3.11/site-packages (from werkzeug>=1.0.1->tensorboard) (2.1.3)
# Requirement already satisfied: mpmath>=0.19 in ./liuhe/lib/python3.11/site-packages (from sympy->torch) (1.3.0)
# Collecting pyasn1<0.6.0,>=0.4.6 (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard)
#   Downloading pyasn1-0.5.0-py2.py3-none-any.whl (83 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 83.9/83.9 kB 7.2 MB/s eta 0:00:00
# Collecting oauthlib>=3.0.0 (from requests-oauthlib>=0.7.0->google-auth-oauthlib<1.1,>=0.5->tensorboard)
#   Using cached oauthlib-3.2.2-py3-none-any.whl (151 kB)
# Using cached tensorboard-2.14.1-py3-none-any.whl (5.5 MB)
# Using cached absl_py-2.0.0-py3-none-any.whl (130 kB)
# Downloading google_auth-2.23.3-py2.py3-none-any.whl (182 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 182.3/182.3 kB 5.4 MB/s eta 0:00:00
# Using cached grpcio-1.59.0-cp311-cp311-macosx_10_10_universal2.whl (9.5 MB)
# Downloading Markdown-3.5-py3-none-any.whl (101 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 101.7/101.7 kB 5.3 MB/s eta 0:00:00
# Using cached tensorboard_data_server-0.7.1-py3-none-any.whl (2.4 kB)
# Using cached cachetools-5.3.1-py3-none-any.whl (9.3 kB)
# Installing collected packages: tensorboard-data-server, pyasn1, oauthlib, markdown, grpcio, cachetools, absl-py, rsa, requests-oauthlib, pyasn1-modules, google-auth, google-auth-oauthlib, tensorboard
# Successfully installed absl-py-2.0.0 cachetools-5.3.1 google-auth-2.23.3 google-auth-oauthlib-1.0.0 grpcio-1.59.0 markdown-3.5 oauthlib-3.2.2 pyasn1-0.5.0 pyasn1-modules-0.3.0 requests-oauthlib-1.3.1 rsa-4.9 tensorboard-2.14.1 tensorboard-data-server-0.7.1

# %%
# PyTorch model and training necessities
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim

# Image datasets and image manipulation
import torchvision
import torchvision.transforms as transforms

# Image display
import matplotlib.pyplot as plt
import numpy as np

# PyTorch TensorBoard support
from torch.utils.tensorboard import SummaryWriter
